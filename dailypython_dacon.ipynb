# %%
import pandas as pd

# %%
# !wget 'https://bit.ly/3gLj0Q6'

import zipfile
with zipfile.ZipFile('3gLj0Q6', 'r') as existing_zip:
  existing_zip.extractall('data')
# Out:
# --2022-09-26 09:51:11--  https://bit.ly/3gLj0Q6
# Resolving bit.ly (bit.ly)... 67.199.248.11, 67.199.248.10
# Connecting to bit.ly (bit.ly)|67.199.248.11|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://drive.google.com/uc?export=download&id=1or_QN1ksv81DNog6Tu_kWcZ5jJWf5W9E [following]
# --2022-09-26 09:51:11--  https://drive.google.com/uc?export=download&id=1or_QN1ksv81DNog6Tu_kWcZ5jJWf5W9E
# Resolving drive.google.com (drive.google.com)... 64.233.189.138, 64.233.189.102, 64.233.189.101, ...
# Connecting to drive.google.com (drive.google.com)|64.233.189.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0c-10-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/uotn982q4q00dfn39itn6vukcoq3ri07/1664185800000/17946651057176172524/*/1or_QN1ksv81DNog6Tu_kWcZ5jJWf5W9E?e=download&uuid=a4913af2-ebf6-4f45-bd72-7cdb3ff16d3d [following]
# Warning: wildcards not supported in HTTP.
# --2022-09-26 09:51:12--  https://doc-0c-10-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/uotn982q4q00dfn39itn6vukcoq3ri07/1664185800000/17946651057176172524/*/1or_QN1ksv81DNog6Tu_kWcZ5jJWf5W9E?e=download&uuid=a4913af2-ebf6-4f45-bd72-7cdb3ff16d3d
# Resolving doc-0c-10-docs.googleusercontent.com (doc-0c-10-docs.googleusercontent.com)... 108.177.125.132, 2404:6800:4008:c01::84
# Connecting to doc-0c-10-docs.googleusercontent.com (doc-0c-10-docs.googleusercontent.com)|108.177.125.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39208 (38K) [application/zip]
# Saving to: ‘3gLj0Q6’
#
# 3gLj0Q6             100%[===================>]  38.29K  --.-KB/s    in 0s
#
# 2022-09-26 09:51:12 (106 MB/s) - ‘3gLj0Q6’ saved [39208/39208]

# %%
train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')

# %%
train.shape
# Out:
# (1459, 11)

# %%
test.shape
# Out:
# (715, 10)

# %%
train.head(10)
# Out:
#    id  hour  hour_bef_temperature  hour_bef_precipitation  hour_bef_windspeed  \
# 0   3    20                  16.3                     1.0                 1.5
# 1   6    13                  20.1                     0.0                 1.4
# 2   7     6                  13.9                     0.0                 0.7
# 3   8    23                   8.1                     0.0                 2.7
# 4   9    18                  29.5                     0.0                 4.8
# 5  13     2                  13.6                     0.0                 1.7
# 6  14     3                  10.6                     0.0                 1.5
# 7  16    21                  16.0                     0.0                 6.0
# 8  19     9                  13.8                     0.0                 1.9
# 9  20    14                  17.2                     0.0                 2.1
#
#    hour_bef_humidity  hour_bef_visibility  hour_bef_ozone  hour_bef_pm10  \
# 0               89.0                576.0           0.027           76.0
# 1               48.0                916.0           0.042           73.0
# 2               79.0               1382.0           0.033           32.0
# 3               54.0                946.0           0.040           75.0
# 4                7.0               2000.0           0.057           27.0
# 5               80.0               1073.0           0.027           34.0
# 6               58.0               1548.0           0.038           62.0
# 7               21.0               1961.0           0.050           90.0
# 8               64.0               1344.0           0.039           93.0
# 9               32.0               1571.0           0.025           64.0
#
#    hour_bef_pm2.5  count
# 0            33.0   49.0
# 1            40.0  159.0
# 2            19.0   26.0
# 3            64.0   57.0
# 4            11.0  431.0
# 5            15.0   39.0
# 6            33.0   23.0
# 7            28.0  146.0
# 8            19.0   39.0
# 9            19.0   83.0

# %%
test.head(10)
# Out:
#    id  hour  hour_bef_temperature  hour_bef_precipitation  hour_bef_windspeed  \
# 0   0     7                  20.7                     0.0                 1.3
# 1   1    17                  30.0                     0.0                 5.4
# 2   2    13                  19.0                     1.0                 2.1
# 3   4     6                  22.5                     0.0                 2.5
# 4   5    22                  14.6                     1.0                 3.4
# 5  10     9                  20.2                     0.0                 4.3
# 6  11    18                  19.0                     0.0                 2.7
# 7  12    18                  31.2                     0.0                 2.2
# 8  15     6                  20.1                     0.0                 0.8
# 9  17     8                  17.0                     1.0                 0.9
#
#    hour_bef_humidity  hour_bef_visibility  hour_bef_ozone  hour_bef_pm10  \
# 0               62.0                954.0           0.041           44.0
# 1               33.0               1590.0           0.061           49.0
# 2               95.0                193.0           0.020           36.0
# 3               60.0               1185.0           0.027           52.0
# 4               93.0                218.0           0.041           18.0
# 5               39.0               2000.0           0.034           22.0
# 6               80.0               2000.0           0.028           17.0
# 7               42.0                621.0           0.117           94.0
# 8               78.0                463.0           0.026           57.0
# 9              100.0                200.0           0.022           12.0
#
#    hour_bef_pm2.5
# 0            27.0
# 1            36.0
# 2            28.0
# 3            38.0
# 4            15.0
# 5             7.0
# 6            12.0
# 7            69.0
# 8            33.0
# 9            12.0
